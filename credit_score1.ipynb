# %%
#importing libraries
import pandas as pd
import numpy as np
# %matplotlib inline 
import os 


import seaborn as sns
import matplotlib.pyplot as plt
import matplotlib.pyplot as plt

sns.set(style='ticks',context='talk')

# %%
apps = pd.read_csv('apps.csv')
loansummary = pd.read_csv('loansummary.csv')
MpesaDeposits = pd.read_csv('MpesaDeposits.csv')
savings = pd.read_csv('Savings.csv')
savingsded = pd.read_csv('SavingsDeductions.csv')
memberdetails = pd.read_csv('memberdetails.csv')

# %%
apps
# Out:
#        memberId                       app_name
# 0        182761                     Truecaller
# 1        182761                 YouCam Perfect
# 2        182761                 Messenger Lite
# 3        182761                      SportPesa
# 4        182761            Audify Music Player
# 5        182761                        Stawika
# 6        182761                       WhatsApp
# 7        182761               Betting Pro Tips
# 8        182761              Tala Haraka Loans
# 9        182761                  Premier Loans
# 10       182761                 My Talking Tom
# 11       182761            MP3 Video Converter
# 12       182761                          OKash
# 13       182761                     Opera Mini
# 14       182761               My Talking Tom 2
# 15       182761                           Kava
# 16       182761                    Best Mirror
# 17       182761                     eCiticenKe
# 18       182761                  Digital Sacco
# ...

# %%
#infomation about the apps entity
apps.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16367 entries, 0 to 16366
# Data columns (total 2 columns):
# memberId    16367 non-null int64
# app_name    16366 non-null object
# dtypes: int64(1), object(1)
# memory usage: 255.8+ KB

# %%
#shape
apps.shape
# Out:
# (16367, 2)

# %%
#checking for the missing values
apps.isnull().sum()
# Out:
# memberId    0
# app_name    1
# dtype: int64

# %%
#List the columns with missing values
apps.columns[apps.isnull().any()].tolist()
# Out:
# ['app_name']

# %%
#Drop the rows where at least one element is missing.
apps.dropna(inplace=True)

# %%
#checking for the missing values
apps.isnull().sum()
# Out:
# memberId    0
# app_name    0
# dtype: int64

# %%
apps['app_name'].value_counts()
# Out:
# Digital Sacco                                         724
# WhatsApp                                              649
# Xender                                                410
# Opera Mini                                            363
# Lite                                                  337
# TALA                                                  311
# Branch                                                286
# Truecaller                                            231
# Instagram                                             219
# OKash                                                 216
# SportPesa                                             215
# Messenger                                             207
# Facebook                                              207
# mySafaricom                                           202
# OPesa                                                 192
# WPS Office                                            164
# ...

# %%
#visualizing the first 20 apps 
apps['app_name'].value_counts()[:20].plot(figsize=(13,13),kind='barh')

# %%
#member id with the highest apps
apps['memberId'].value_counts()
# Out:
# 184680    167
# 184308    158
# 183414    117
# 189376    107
# 183855    103
# 183193    102
# 98939      98
# 184407     82
# 187303     82
# 135831     79
# 6113       78
# 179499     77
# 151432     75
# 183807     72
# 184747     72
# 181201     72
# 188868     70
# 184422     70
# 183766     68
# 134866     68
# 121942     67
# 183951     67
# 151968     66
# 77055      64
# 185812     64
# 141909     63
# 178016     63
# 187388     62
# 182860     59
# 184674     58
#          ...
# 183908      5
# 182928      5
# 183294      4
# 186443      4
# 186430      4
# 183146      4
# 148931      4
# 186136      4
# 179421      4
# 175156      4
# 95013       4
# 168815      4
# 35596       4
# 183459      4
# 71846       4
# 122419      4
# 183973      3
# 183938      3
# 116212      3
# 183081      3
# 24934       3
# 160315      3
# 168252      3
# 183127      3
# 185212      3
# 127631      2
# 184178      2
# 186528      2
# 183831      2
# 74909       2
# ...

# %%
#plotting memberIds with the highest number of apps
savings['memberId'].value_counts()[:20].plot(figsize =(13,13),kind='barh')

# %%
#converting  to csv file
apps.reset_index(inplace = True)
apps.to_csv('appsded.csv', index = False)

# %%
savings
# Out:
#       memberId     amount              description       dateCreated
# 0          391     150.00              From Wallet   11/5/2015 22:58
# 1          391     250.00              From Wallet  11/11/2015 10:00
# 2          391     100.00              From Wallet  11/12/2015 11:35
# 3         4790     500.00              From Wallet  11/14/2015 17:41
# 4         7171     500.00              From Wallet  11/22/2015 16:54
# 5         7171   1,500.00              From Wallet   11/29/2015 8:50
# 6         2397      35.00              From Wallet   12/8/2015 12:57
# 7         2414   2,000.00              From Wallet   12/8/2015 12:57
# 8         4790      80.00              From Wallet   12/8/2015 12:57
# 9         8104     500.00              From Wallet   12/8/2015 12:57
# 10        7171   3,000.00              From Wallet  12/13/2015 13:22
# 11        4790     300.00              From Wallet  12/14/2015 15:30
# 12        7171   2,000.00              From Wallet  12/19/2015 16:01
# ...

# %%
savings.dtypes
# Out:
# memberId        int64
#  amount        object
# description    object
# dateCreated    object
# dtype: object

# %%
#FINDING INFORMATION ABOUT THE DATA
savings.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2488 entries, 0 to 2487
# Data columns (total 4 columns):
# memberId       2488 non-null int64
#  amount        2488 non-null object
# description    2488 non-null object
# dateCreated    2488 non-null object
# dtypes: int64(1), object(3)
# memory usage: 77.8+ KB

# %%
#check the variables in the column
savings.columns
# Out:
# Index(['memberId', ' amount ', 'description', 'dateCreated'], dtype='object')

# %%
#check the missing values 
savings.isnull().sum()
# Out:
# memberId       0
#  amount        0
# description    0
# dateCreated    0
# dtype: int64

# %%
savings.shape
# Out:
# (2488, 4)

# %%
#Check a heatmap of missing values

sns.heatmap(savings.isnull(),yticklabels=False,cbar=False,cmap='viridis')

# %%
savings.head(3)
# Out:
#    memberId   amount   description       dateCreated
# 0       391   150.00   From Wallet   11/5/2015 22:58
# 1       391   250.00   From Wallet  11/11/2015 10:00
# 2       391   100.00   From Wallet  11/12/2015 11:35

# %%
savings.head(3)
# Out:
#    memberId   amount   description       dateCreated
# 0       391   150.00   From Wallet   11/5/2015 22:58
# 1       391   250.00   From Wallet  11/11/2015 10:00
# 2       391   100.00   From Wallet  11/12/2015 11:35

# %%
#counts on the description
savings['description'].value_counts()
# Out:
# From Wallet               1755
# Automatic Contribution     727
# Exit From Pool               6
# Name: description, dtype: int64

# %%
#plotting the description counts
sns.countplot(x='description', data=savings, palette='Set2')
plt.show()

# %%
savings.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2488 entries, 0 to 2487
# Data columns (total 4 columns):
# memberId       2488 non-null int64
#  amount        2488 non-null object
# description    2488 non-null object
# dateCreated    2488 non-null object
# dtypes: int64(1), object(3)
# memory usage: 77.8+ KB

# %%
savings.head(2)
# Out:
#    memberId   amount   description       dateCreated
# 0       391   150.00   From Wallet   11/5/2015 22:58
# 1       391   250.00   From Wallet  11/11/2015 10:00

# %%
#listing all the data types
savings.dtypes
# Out:
# memberId        int64
#  amount        object
# description    object
# dateCreated    object
# dtype: object

# %%
#displaying the amount datatype
savings.amount
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-292-f0b1fa6b76e0> in <module>()
#       1 #displaying the amount datatype
# ----> 2 savings.amount
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/generic.py in __getattr__(self, name)
#    4374             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    4375                 return self[name]
# -> 4376             return object.__getattribute__(self, name)
#    4377
#    4378     def __setattr__(self, name, value):
#
# AttributeError: 'DataFrame' object has no attribute 'amount'

# %%
#rechanging the column name
col_name =savings.columns[1]
savings=savings.rename(columns = {col_name:'amount'})

# %%
#checking the process again
savings.amount
# Out:
# 0          150.00
# 1          250.00
# 2          100.00
# 3          500.00
# 4          500.00
# 5        1,500.00
# 6           35.00
# 7        2,000.00
# 8           80.00
# 9          500.00
# 10       3,000.00
# 11         300.00
# 12       2,000.00
# 13         200.00
# 14         400.00
# 15       3,000.00
# 16         900.00
# 17       1,800.00
# 18         300.00
# 19         900.00
# 20       3,800.00
# 21       1,000.00
# 22       1,500.00
# 23         500.00
# 24         650.00
# 25         190.00
# 26         200.00
# 27         200.00
# 28         450.00
# 29         150.00
#            ...
# 2458       100.00
# 2459       180.00
# 2460       570.00
# 2461     1,100.00
# 2462       500.00
# 2463       200.00
# 2464        20.00
# 2465       450.00
# 2466       250.00
# 2467       100.00
# 2468       100.00
# 2469     1,000.00
# 2470        58.00
# 2471         0.06
# 2472       152.25
# 2473       500.00
# 2474       100.00
# 2475     1,000.00
# 2476       900.00
# ...

# %%
#looking at the datatypes of the objects
savings.dtypes
# Out:
# memberId        int64
# amount         object
# description    object
# dateCreated    object
# dtype: object

# %%
##To remove white space everywhere:
savings.columns = savings.columns.str.replace(' ', '')

# %%
#To remove white space everywhere:

savings.columns = savings.columns.str.replace(' ', '')

#To remove white space at the beginning of string:

savings.columns = savings.columns.str.lstrip()

#To remove white space at the end of string:

savings.columns = savings.columns.str.rstrip()

# To remove white space at both ends:

savings.columns = savings.columns.str.strip()

# %%
savings["amount"] = savings["amount"].str.strip()

# %%
#stripping all the white spaces and columns in the savings dataset 
savings["amount"] = savings["amount"].str.replace(',', '')

# %%
#amount now turns to be a float type
savings["amount"] = savings["amount"].astype(str).astype(float)
savings.dtypes
# Out:
# memberId         int64
# amount         float64
# description     object
# dateCreated     object
# dtype: object

# %%
#splitting dateCreated into years 
savings['Years'] = pd.to_datetime(savings['dateCreated']).dt.year
group_by_Years = savings.groupby(by=['Years'])
savings_data_count = group_by_Years.count()

# %%
savings_data_count
# Out:
#        memberId   amount   description  dateCreated
# Years
# 2015         25        25           25           25
# 2016        167       167          167          167
# 2017        238       238          238          238
# 2018        715       715          715          715
# 2019       1343      1343         1343         1343

# %%
#savings head
savings.head(4)
# Out:
#    memberId   amount   description       dateCreated  Years
# 0       391   150.00   From Wallet   11/5/2015 22:58   2015
# 1       391   250.00   From Wallet  11/11/2015 10:00   2015
# 2       391   100.00   From Wallet  11/12/2015 11:35   2015
# 3      4790   500.00   From Wallet  11/14/2015 17:41   2015

# %%
#check at how the amount price is distributed
print(savings['amount'].describe())
plt.figure(figsize=(9,8))
sns.distplot(savings['amount'],color = 'g',bins = 100,hist_kws={'alpha':0.4});
# Out:
# count     2488.000000
# mean       582.879960
# std       2548.033044
# min          0.010000
# 25%         50.000000
# 50%        100.000000
# 75%        484.000000
# max      62133.000000
# Name: amount, dtype: float64
# /home/kevin_ochieng/anaconda3/lib/python3.7/site-packages/scipy/stats/stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %%
#further look at the amount distribution distributibution
plt.subplot(121) 
sns.distplot(savings['amount']); 
plt.subplot(122) 
savings['amount'].plot.box(figsize=(16,5)) 
plt.show()
# Out:
# /home/kevin_ochieng/anaconda3/lib/python3.7/site-packages/scipy/stats/stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %%
#assigning x to the savings amount
x= savings['amount']

# %%
#normalizing using z-score threshold <3
from scipy import stats
import numpy as np
z = np.abs(stats.zscore(x))

# %%
savings['amount'] = x[(z < 3)]

# %%
#outlayers removed from the amount
savings.isnull().sum()
# Out:
# memberId        0
# amount         26
# description     0
# dateCreated     0
# dtype: int64

# %%
#removing all the missing values in the column amount 
#Drop the rows where at least one element is missing.
savings.dropna(inplace=True)

# %%
#further look at the amount distribution distributibution
plt.subplot(121) 
sns.distplot(savings['amount']); 
plt.subplot(122) 
savings['amount'].plot.box(figsize=(16,5)) 
plt.show()
# Out:
# /home/kevin_ochieng/anaconda3/lib/python3.7/site-packages/scipy/stats/stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %%
#plotting logs of savings amount 
plt.subplot(121)
savings['amount'] = np.log(savings['amount']) 
sns.distplot(savings['amount']);
plt.subplot(122)
savings['amount'].plot.box(figsize=(16,5)) 
plt.show()
# Out:
# /home/kevin_ochieng/anaconda3/lib/python3.7/site-packages/scipy/stats/stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %%
#converting  to csv file
savings.reset_index(inplace = True)
savings.to_csv('savings_ded.csv', index = False)

# %%
#displaying savings deduction entities 
savingsded
# Out:
#      memberId Loan Id     debit          description      dateCreated
# 0         391     178        420       Loan Recovery  7/27/2017 16:52
# 1         391     178         80       Loan Recovery  7/27/2017 16:52
# 2        1813    2183   1,260.00       Loan Recovery  7/27/2017 17:31
# 3        1813    2183        300       Loan Recovery  7/27/2017 17:31
# 4        7171    3759  11,767.80       Loan Recovery  7/27/2017 17:55
# 5       24861    6324   1,032.58       Loan Recovery  7/27/2017 17:56
# 6       24861    6324     167.95       Loan Recovery  7/27/2017 17:56
# 7        7171    7923   2,100.00       Loan Recovery  7/27/2017 18:10
# 8        9916   12313   4,947.80       Loan Recovery  7/27/2017 18:44
# 9        9916   12322  14,628.30       Loan Recovery  7/27/2017 18:44
# 10       9916   12716   3,226.82       Loan Recovery  7/27/2017 18:44
# 11       9916   13393     489.36       Loan Recovery  7/27/2017 18:44
# ...

# %%
#checking at the data info
savingsded.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 188 entries, 0 to 187
# Data columns (total 5 columns):
# memberId       188 non-null int64
# Loan Id        188 non-null object
#  debit         188 non-null object
# description    188 non-null object
# dateCreated    188 non-null object
# dtypes: int64(1), object(4)
# memory usage: 7.4+ KB

# %%
#checking the columns 
savingsded.columns
# Out:
# Index(['memberId', 'Loan Id', ' debit ', 'description', 'dateCreated'], dtype='object')

# %%
#check the missing values 
savingsded.isnull().sum()
# Out:
# memberId       0
# Loan Id        0
#  debit         0
# description    0
# dateCreated    0
# dtype: int64

# %%
#Check a heatmap of missing values

sns.heatmap(savingsded.isnull(),yticklabels=False,cbar=False,cmap='viridis')

# %%
savingsded.head(3)
# Out:
#    memberId Loan Id    debit     description      dateCreated
# 0       391     178       420  Loan Recovery  7/27/2017 16:52
# 1       391     178        80  Loan Recovery  7/27/2017 16:52
# 2      1813    2183  1,260.00  Loan Recovery  7/27/2017 17:31

# %%
#checking the data types
savingsded.dtypes
# Out:
# memberId        int64
# Loan Id        object
#  debit         object
# description    object
# dateCreated    object
# dtype: object

# %%
#displaying loanId 
savingsded.LoanId
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-237-9b5b30d4a645> in <module>()
#       1 #displaying loanId
# ----> 2 savingsded.LoanId
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/generic.py in __getattr__(self, name)
#    4374             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    4375                 return self[name]
# -> 4376             return object.__getattribute__(self, name)
#    4377
#    4378     def __setattr__(self, name, value):
#
# AttributeError: 'DataFrame' object has no attribute 'LoanId'

# %%
#rechanging the column name for loanId
col_name =savingsded.columns[1]
savingsded=savingsded.rename(columns = {col_name:'loanId'})

# %%
#confirming the changes 
savingsded.loanId
# Out:
# 0        178
# 1        178
# 2       2183
# 3       2183
# 4       3759
# 5       6324
# 6       6324
# 7       7923
# 8      12313
# 9      12322
# 10     12716
# 11     13393
# 12     14093
# 13     15207
# 14     15207
# 15     16497
# 16     16499
# 17     17290
# 18     10774
# 19      4846
# 20      4927
# 21      5285
# 22      5503
# 23      5676
# 24      5910
# 25      6115
# 26      6776
# 27      7393
# 28      8018
# 29      8109
#        ...
# 158    90119
# 159    91229
# 160     Pool
# 161     Pool
# 162     Pool
# 163     Pool
# 164     Pool
# 165    88066
# 166    88066
# 167    88081
# 168    88081
# 169     Pool
# 170     Pool
# 171     Pool
# 172    87105
# 173    97866
# 174    97828
# 175    97828
# 176    97828
# 177    98122
# 178    98122
# 179    98122
# 180     Pool
# 181     Pool
# 182     Pool
# 183    89385
# 184     Pool
# 185     Pool
# 186     Pool
# 187     Pool
# Name: loanId, Length: 188, dtype: object

# %%
#To remove white space everywhere:

savingsded.columns = savingsded.columns.str.replace(' ', '')

#To remove white space at the beginning of string:

savingsded.columns = savingsded.columns.str.lstrip()

#To remove white space at the end of string:

savingsded.columns = savingsded.columns.str.rstrip()

# To remove white space at both ends:

savingsded.columns = savingsded.columns.str.strip()

# %%
savingsded["loanId"] = savingsded["loanId"].str.strip()

# %%
#stripping all the white spaces and columns in the savings dataset 
savingsded["loanId"] = savingsded["loanId"].str.replace(',', '')

# %%
#stripping all the white spaces and columns in the savings dataset 
savingsded["loanId"] = savingsded["loanId"].str.replace('-', '0')

# %%
#converting the debit object to float type
savingsded["loanId"] = savingsded["loanId"].astype(str).astype(float)
savingsded.dtypes
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-244-71f4084fa499> in <module>()
#       1 #converting the debit object to float type
# ----> 2 savingsded["loanId"] = savingsded["loanId"].astype(str).astype(float)
#       3 savingsded.dtypes
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     176                 else:
#     177                     kwargs[new_arg_name] = new_arg_value
# --> 178             return func(*args, **kwargs)
#     179         return wrapper
#     180     return _deprecate_kwarg
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/generic.py in astype(self, dtype, copy, errors, **kwargs)
#    4999             # else, only a single dtype is given
#    5000             new_data = self._data.astype(dtype=dtype, copy=copy, errors=errors,
# ...

# %%
#
savingsded.loanId
# Out:
# 0        178
# 1        178
# 2       2183
# 3       2183
# 4       3759
# 5       6324
# 6       6324
# 7       7923
# 8      12313
# 9      12322
# 10     12716
# 11     13393
# 12     14093
# 13     15207
# 14     15207
# 15     16497
# 16     16499
# 17     17290
# 18     10774
# 19      4846
# 20      4927
# 21      5285
# 22      5503
# 23      5676
# 24      5910
# 25      6115
# 26      6776
# 27      7393
# 28      8018
# 29      8109
#        ...
# 158    90119
# 159    91229
# 160     Pool
# 161     Pool
# 162     Pool
# 163     Pool
# 164     Pool
# 165    88066
# 166    88066
# 167    88081
# 168    88081
# 169     Pool
# 170     Pool
# 171     Pool
# 172    87105
# 173    97866
# 174    97828
# 175    97828
# 176    97828
# 177    98122
# 178    98122
# 179    98122
# 180     Pool
# 181     Pool
# 182     Pool
# 183    89385
# 184     Pool
# 185     Pool
# 186     Pool
# 187     Pool
# Name: loanId, Length: 188, dtype: object

# %%
#method 2 of the solution now works!
savingsded.loanId[savingsded.loanId == 'Pool'] = 5
savingsded.loanId[savingsded.loanId == 'Reversal'] = 6
savingsded.loanId[savingsded.loanId == 'Exit from Sacco'] = 7
# Out:
# /home/kevin_ochieng/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#
# /home/kevin_ochieng/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# /home/kevin_ochieng/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# ...

# %%
#confirming the conversion
savingsded.loanId
# Out:
# 0        178
# 1        178
# 2       2183
# 3       2183
# 4       3759
# 5       6324
# 6       6324
# 7       7923
# 8      12313
# 9      12322
# 10     12716
# 11     13393
# 12     14093
# 13     15207
# 14     15207
# 15     16497
# 16     16499
# 17     17290
# 18     10774
# 19      4846
# 20      4927
# 21      5285
# 22      5503
# 23      5676
# 24      5910
# 25      6115
# 26      6776
# 27      7393
# 28      8018
# 29      8109
#        ...
# 158    90119
# 159    91229
# 160        5
# 161        5
# 162        5
# 163        5
# 164        5
# 165    88066
# 166    88066
# 167    88081
# 168    88081
# 169        5
# 170        5
# 171        5
# 172    87105
# 173    97866
# 174    97828
# 175    97828
# 176    97828
# 177    98122
# 178    98122
# 179    98122
# 180        5
# 181        5
# 182        5
# 183    89385
# 184        5
# 185        5
# 186        5
# 187        5
# Name: loanId, Length: 188, dtype: object

# %%
#displaying the data types again
savingsded.dtypes
# Out:
# memberId        int64
# loanId         object
# debit          object
# description    object
# dateCreated    object
# dtype: object

# %%
#checking the loanId
savingsded.loanId
# Out:
# 0        178
# 1        178
# 2       2183
# 3       2183
# 4       3759
# 5       6324
# 6       6324
# 7       7923
# 8      12313
# 9      12322
# 10     12716
# 11     13393
# 12     14093
# 13     15207
# 14     15207
# 15     16497
# 16     16499
# 17     17290
# 18     10774
# 19      4846
# 20      4927
# 21      5285
# 22      5503
# 23      5676
# 24      5910
# 25      6115
# 26      6776
# 27      7393
# 28      8018
# 29      8109
#        ...
# 158    90119
# 159    91229
# 160        5
# 161        5
# 162        5
# 163        5
# 164        5
# 165    88066
# 166    88066
# 167    88081
# 168    88081
# 169        5
# 170        5
# 171        5
# 172    87105
# 173    97866
# 174    97828
# 175    97828
# 176    97828
# 177    98122
# 178    98122
# 179    98122
# 180        5
# 181        5
# 182        5
# 183    89385
# 184        5
# 185        5
# 186        5
# 187        5
# Name: loanId, Length: 188, dtype: object

# %%
#converting the debit object to float type
savingsded["loanId"] = savingsded["loanId"].astype(str).astype(float)
savingsded.dtypes
# Out:
# memberId         int64
# loanId         float64
# debit           object
# description     object
# dateCreated     object
# dtype: object

# %%
#checking if the column debit exists
savingsded.debit
# Out:
# 0            420
# 1             80
# 2       1,260.00
# 3            300
# 4      11,767.80
# 5       1,032.58
# 6         167.95
# 7       2,100.00
# 8       4,947.80
# 9      14,628.30
# 10      3,226.82
# 11        489.36
# 12          -
# 13           400
# 14         60.51
# 15      2,414.08
# 16      2,415.00
# 17         726.6
# 18      8,062.50
# 19      1,800.00
# 20      3,554.40
# 21      2,520.00
# 22      2,568.00
# 23      1,224.00
# 24      1,044.00
# 25      2,946.40
# 26      1,376.92
# 27           560
# 28      1,128.60
# 29      5,650.08
#          ...
# 158        53.21
# 159     1,681.25
# 160     2,200.00
# 161          532
# 162          300
# 163          100
# 164          400
# 165           30
# 166    10,304.00
# 167          216
# 168     9,936.00
# 169           10
# 170          200
# 171          200
# 172     7,256.19
# 173           75
# 174        56.25
# 175     2,362.50
# 176        81.87
# 177        50.33
# 178     2,239.65
# 179        80.28
# ...

# %%
#To remove white space everywhere:

savingsded.columns = savingsded.columns.str.replace(' ', '')

#To remove white space at the beginning of string:

savingsded.columns = savingsded.columns.str.lstrip()

#To remove white space at the end of string:

savingsded.columns = savingsded.columns.str.rstrip()

# To remove white space at both ends:

savingsded.columns = savingsded.columns.str.strip()

# %%
#converting debit object to float type
savingsded["debit"] = savingsded["debit"].str.strip('')

# %%
#stripping all the white spaces and columns in the savings dataset 
savingsded["debit"] = savingsded["debit"].str.replace(',', '')

# %%
savingsded["debit"] = savingsded["debit"].str.replace('-', '0')

# %%
#converting the loanId  object to float type
savingsded["debit"] = savingsded["debit"].astype(str).astype(float)
savingsded.dtypes
# Out:
# memberId         int64
# loanId         float64
# debit          float64
# description     object
# dateCreated     object
# dtype: object

# %%
savingsded.isnull().sum()
# Out:
# memberId       0
# loanId         0
# debit          0
# description    0
# dateCreated    0
# dtype: int64

# %%
#checking the datatypes again
savingsded.dtypes
# Out:
# memberId         int64
# loanId         float64
# debit          float64
# description     object
# dateCreated     object
# dtype: object

# %%
#checking for missing values 
savingsded.isnull().sum()
# Out:
# memberId       0
# loanId         0
# debit          0
# description    0
# dateCreated    0
# dtype: int64

# %%
#displaying 4 raws
savingsded.head(4)
# Out:
#    memberId  loanId   debit    description      dateCreated
# 0       391   178.0   420.0  Loan Recovery  7/27/2017 16:52
# 1       391   178.0    80.0  Loan Recovery  7/27/2017 16:52
# 2      1813  2183.0  1260.0  Loan Recovery  7/27/2017 17:31
# 3      1813  2183.0   300.0  Loan Recovery  7/27/2017 17:31

# %%
#plotting a count of savings deduction description
savingsded['description'].value_counts(normalize=True).plot.bar(figsize=(20,10), title= 'A plot of count on description of savings deduction')

# %%
savingsded.head(3)
# Out:
#    memberId  loanId   debit    description      dateCreated
# 0       391   178.0   420.0  Loan Recovery  7/27/2017 16:52
# 1       391   178.0    80.0  Loan Recovery  7/27/2017 16:52
# 2      1813  2183.0  1260.0  Loan Recovery  7/27/2017 17:31

# %%
savingsded.isnull().sum()
# Out:
# memberId       0
# loanId         0
# debit          0
# description    0
# dateCreated    0
# dtype: int64

# %%
#ploting the distribution and checking outlayers for debit
plt.subplot(121) 
sns.distplot(savingsded['debit']); 
plt.subplot(122) 
savingsded['debit'].plot.box(figsize=(16,5)) 
plt.show()
# Out:
# /home/kevin_ochieng/anaconda3/lib/python3.7/site-packages/scipy/stats/stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %%
#assigning x to the savingsded debit
x= savingsded['debit']
#normalizing using z-score threshold <3

# %%
from scipy import stats
import numpy as np
z = np.abs(stats.zscore(x))
savingsded['debit'] = x[(z < 3)]

# %%
#checking for missing values 
savingsded.isnull().sum()
# Out:
# memberId       0
# loanId         0
# debit          4
# description    0
# dateCreated    0
# dtype: int64

# %%
#removing all the missing values in the column debit 
#Drop the rows where at least one element is missing.
savingsded.dropna(inplace=True)
#further look at the debit distribution distributibution

# %%
plt.subplot(121)
sns.distplot(savingsded['debit']); 
plt.subplot(122) 
savingsded['debit'].plot.box(figsize=(16,5)) 
plt.show()
# Out:
# /home/kevin_ochieng/anaconda3/lib/python3.7/site-packages/scipy/stats/stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %%
#converting the processed savingsded to csv file
savingsded.reset_index(inplace = True)
savingsded.to_csv('savingsded.csv', index = False)

# %%
#displaying the first 5 raws
memberdetails.head(4)
# Out:
#    memberId   county       dateCreated  pledge  TARGET
# 0       391    BOMET   9/26/2015 11:37     500       1
# 1       752  Nairobi  10/15/2015 10:20    1000       0
# 2       873  NAIROBI  10/16/2015 18:51     500       0
# 3      1813    KENYA  10/27/2015 22:19     500       1

# %%
#more information about the data
memberdetails.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 698 entries, 0 to 697
# Data columns (total 5 columns):
# memberId       698 non-null int64
# county         698 non-null object
# dateCreated    698 non-null object
# pledge         698 non-null int64
# TARGET         698 non-null int64
# dtypes: int64(3), object(2)
# memory usage: 27.3+ KB

# %%
#shape of member details
memberdetails.shape
# Out:
# (698, 5)

# %%
memberdetails.head(3)
# Out:
#    memberId   county       dateCreated  pledge  TARGET
# 0       391    BOMET   9/26/2015 11:37     500       1
# 1       752  Nairobi  10/15/2015 10:20    1000       0
# 2       873  NAIROBI  10/16/2015 18:51     500       0

# %%
#checking for missing values 
memberdetails.isnull().sum()
# Out:
# memberId       0
# county         0
# dateCreated    0
# pledge         0
# TARGET         0
# dtype: int64

# %%
memberdetails.county
# Out:
# 0                 BOMET
# 1               Nairobi
# 2               NAIROBI
# 3                 KENYA
# 4                 NAROK
# 5               Nairobi
# 6                vihiga
# 7                KISUMU
# 8              Machakos
# 9      tranz nzoia west
# 10              Nairobi
# 11     Elgeiyo Marakwet
# 12               Kiambu
# 13               kilifi
# 14                Kenya
# 15                kenya
# 16                Nyeri
# 17              Nairobi
# 18              NAIROBI
# 19              Nairobi
# 20               Nakuru
# 21                KENYA
# 22     Alexander munene
# 23              NAIROBI
# 24               kiambu
# 25              NIL_CTY
# 26              NIL_CTY
# 27              NIL_CTY
# 28              NIL_CTY
# 29              NIL_CTY
#              ...
# 668             kericho
# 669            machakos
# 670           kirinyaga
# 671             bungoma
# 672             turkana
# 673              kisumu
# 674              kilifi
# ...

# %%
# changing to upper case county 
memberdetails['county'] = memberdetails['county'].str.upper()

# %%
memberdetails.head(4)
# Out:
#    memberId   county       dateCreated  pledge  TARGET
# 0       391    BOMET   9/26/2015 11:37     500       1
# 1       752  NAIROBI  10/15/2015 10:20    1000       0
# 2       873  NAIROBI  10/16/2015 18:51     500       0
# 3      1813    KENYA  10/27/2015 22:19     500       1

# %%
#clearning county column
memberdetails.county= memberdetails.county.replace({'BOMERT': 'BOMET','BUNGONA':'BUNGOMA',
'BUSIA KENYA': 'BUSIA','40305':'HOMA BAY','HOMA-BAY':'HOMA BAY', 'HOMABAY':'HOMA BAY', 'KAJIANDO':'KAJIADO',
'KAJOADO':'KAJIADO','KAKAMEG':'KAKAMEGA','KENYA':'KENYA','KENYAN':'KENYA','KENYS':'KENYA',
'KERICHO.':'KERICHO','KIRINYANGA':'KIRINYAGA','TAITA':'TAITA TAVETA','TAITATAVETA':'TAITA TAVETA',
'TRANS-NZOIA':'TRANS NZOIA','TRANSNZOIA':'TRANS NZOIA','TRANZ NZOIA WEST':'TRANS NZOIA','KITALE':'TRANS NZOIA',
'TRANZ NZOIA':'TRANS NZOIA','TRUKANA':'TURKANA','TURKANA':'TURKANA','UASHINGISHU':'UASIN GISHU',
'UASIN NGISHU':'UASIN GISHU','UASINGISHU':'UASIN GISHU','USIN GISHU':'UASIN GISHU',
'UASIL GISHU':'UASIN GISHU','UASIN GISH':'UASIN GISHU','EIDORET':'UASIN GISHU','NAIROBI COUNTY':'NAIROBI',
'NRB':'NAIROBI','MAKANDARA':'NAIROBI','KISUMU COUNTY':'KISUMU','NYAKACH':'KISUMU','NANDI COUNTY':'NANDI','NAIROBI':'NAIROBI',
'LAIKIPOA':'LAIKIPIA','SOLOMON':'NIL_CTY','ALEXANDER MUNENE':'NIL_CTY','ODEK':'NIL_CTY',
"MURANG'A":'MURANGA', 'MERU':'MERU COUNTY','THIKA':'KIAMBU','WUNDANYI':'MOMBASA',
'NYADARUA':'NYANDARUA','LAKIPIA':'LAIKIPIA','MWEA':'KIRINYAGA','NGONG':'KAJIADO'})

# %%
memberdetails.county
# Out:
# 0                 BOMET
# 1               NAIROBI
# 2               NAIROBI
# 3                 KENYA
# 4                 NAROK
# 5               NAIROBI
# 6                VIHIGA
# 7                KISUMU
# 8              MACHAKOS
# 9           TRANS NZOIA
# 10              NAIROBI
# 11     ELGEIYO MARAKWET
# 12               KIAMBU
# 13               KILIFI
# 14                KENYA
# 15                KENYA
# 16                NYERI
# 17              NAIROBI
# 18              NAIROBI
# 19              NAIROBI
# 20               NAKURU
# 21                KENYA
# 22              NIL_CTY
# 23              NAIROBI
# 24               KIAMBU
# 25              NIL_CTY
# 26              NIL_CTY
# 27              NIL_CTY
# 28              NIL_CTY
# 29              NIL_CTY
#              ...
# 668             KERICHO
# 669            MACHAKOS
# 670           KIRINYAGA
# 671             BUNGOMA
# 672             TURKANA
# 673              KISUMU
# 674              KILIFI
# ...

# %%
#check the missing values
memberdetails.isnull().sum()
# Out:
# memberId       0
# county         0
# dateCreated    0
# pledge         0
# TARGET         0
# dtype: int64

# %%
memberdetails.head(3)
# Out:
#    memberId   county       dateCreated  pledge  TARGET
# 0       391    BOMET   9/26/2015 11:37     500       1
# 1       752  NAIROBI  10/15/2015 10:20    1000       0
# 2       873  NAIROBI  10/16/2015 18:51     500       0

# %%
#target variable counts
memberdetails['TARGET'].value_counts().plot.bar()

# %%
#plotting target variable with respect to various counties 
#Let us look at the stacked bar plot now which will give us the proportion of approved and unapproved loans.
county= pd.crosstab(memberdetails['county'],memberdetails['TARGET'])
county.div(county.sum(1).astype(float), axis=0).plot(kind="bar",stacked=True,figsize=(20,10))

# %%
#a countplot of counties
#plotting a count of counties with frequent pledges
memberdetails['county'].value_counts(normalize=True).plot.bar(figsize=(20,10), title= 'county with frequent pledges')

# %%
sns.countplot(x='survived',hue='class',data=df)

# %%
#plotting target with the highest pledge

plt.figure(figsize=(30,7))
sns.barplot(x='TARGET',y='pledge',data=memberdetails,palette='winter')
# Out:
# /home/kevin_ochieng/anaconda3/lib/python3.7/site-packages/scipy/stats/stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %%
plt.figure(figsize=(30,7))
sns.barplot(x='county',y='pledge',data=memberdetails,palette='winter')
# Out:
# /home/kevin_ochieng/anaconda3/lib/python3.7/site-packages/scipy/stats/stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %%
#ommitng raws with 0s in a column 
memberdetils = memberdetails[memberdetails.pledge_500 != 0]

# %%
#ommiting rows with negatives
memberdetils = memberdetails[memberdetails.pledge_500 >= 0]

# %%
#Let’s look at the  pleage distribution
plt.subplot(121) 
sns.distplot(memberdetails['pledge']); 
plt.subplot(122) 
memberdetails['pledge'].plot.box(figsize=(16,5)) 
plt.show()
#ASSUMPTION OF LINEARITY OF INDEPENDENT VARIABLES AND LOG ODDS
# Out:
# /home/kevin_ochieng/anaconda3/lib/python3.7/site-packages/scipy/stats/stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %%
#normalize using logs 
#normalizing amount using log
plt.subplot(121)
memberdetails['pledge'] = np.log(memberdetails['pledge']) 
sns.distplot(memberdetails['pledge']);
plt.subplot(122)
memberdetails['pledge'].plot.box(figsize=(16,5)) 
plt.show()
# Out:
# /home/kevin_ochieng/anaconda3/lib/python3.7/site-packages/scipy/stats/stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %%
#using z score
#assigning x to the pledge
x= memberdetails['pledge']

# %%
#normalizing using z-score threshold <3
from scipy import stats
import numpy as np
z = np.abs(stats.zscore(x))

# %%
memberdetails['pledge'] = x[(z < 3)]
#outlayers removed from the pledge
memberdetails.isnull().sum()
# Out:
# memberId       0
# county         0
# dateCreated    0
# pledge         3
# TARGET         0
# dtype: int64

# %%
#removing all the missing values in the column amount 
#Drop the rows where at least one element is missing.
memberdetails.dropna(inplace=True)

# %%
#further look at the amount distribution distributibution
plt.subplot(121) 
sns.distplot(memberdetails['pledge']); 
plt.subplot(122) 
memberdetails['pledge'].plot.box(figsize=(16,5)) 
plt.show()
# Out:
# /home/kevin_ochieng/anaconda3/lib/python3.7/site-packages/scipy/stats/stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %%
memberdetails.head(4)
# Out:
#    memberId   county       dateCreated  pledge
# 0       391    BOMET   9/26/2015 11:37   500.0
# 1       752  NAIROBI  10/15/2015 10:20  1000.0
# 2       873  NAIROBI  10/16/2015 18:51   500.0
# 3      1813    KENYA  10/27/2015 22:19   500.0

# %%
#converting memberdetails to csv file
#converting  to csv file
memberdetails.reset_index(inplace = True)
memberdetails.to_csv('memberdetails_ded.csv', index = False)

# %%
MpesaDeposits
# Out:
#          amount   memberId  transaction_date
# 0         50.00        391   9/26/2015 12:05
# 1        150.00        391   9/29/2015 14:08
# 2        150.00        391   10/6/2015 17:10
# 3        200.00        752  10/15/2015 10:29
# 4        200.00       2414   11/3/2015 17:18
# 5        250.00        391   11/11/2015 9:56
# 6        100.00        391  11/12/2015 11:29
# 7        200.00       4790  11/13/2015 20:50
# 8         50.00       4790  11/13/2015 20:52
# 9         30.00       4790  11/13/2015 21:03
# 10       500.00       4790  11/14/2015 17:35
# 11     2,000.00       2414  11/19/2015 18:03
# 12       200.00       7171  11/22/2015 16:16
# 13     2,000.00       7171  11/22/2015 16:19
# 14       200.00       8104  11/26/2015 21:14
# 15       100.00       8104  11/30/2015 22:32
# 16        80.00       8104   12/1/2015 13:21
# 17        10.00       2397   12/2/2015 10:27
# 18       200.00       2397    12/5/2015 7:09
# 19        25.00       2397   12/6/2015 10:54
# ...

# %%
#get mmore informatin about mpesadetails
MpesaDeposits.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3311 entries, 0 to 3310
# Data columns (total 3 columns):
#  amount             3311 non-null object
# memberId            3311 non-null int64
# transaction_date    3311 non-null object
# dtypes: int64(1), object(2)
# memory usage: 77.7+ KB

# %%
#displaying first 4 raws
MpesaDeposits.head(4)
# Out:
#     amount   memberId  transaction_date
# 0    50.00        391   9/26/2015 12:05
# 1   150.00        391   9/29/2015 14:08
# 2   150.00        391   10/6/2015 17:10
# 3   200.00        752  10/15/2015 10:29

# %%
#checking the shape of the dataset
MpesaDeposits.shape
# Out:
# (3311, 3)

# %%
#checking for missing values 
MpesaDeposits.isnull().sum()
# Out:
#  amount             0
# memberId            0
# transaction_date    0
# dtype: int64

# %%
#converting amount to float

# %%
#loading the amount column
MpesaDeposits.amount
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-315-927825be8b00> in <module>()
#       1 #loading the amount column
# ----> 2 MpesaDeposits.amount
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/generic.py in __getattr__(self, name)
#    4374             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    4375                 return self[name]
# -> 4376             return object.__getattribute__(self, name)
#    4377
#    4378     def __setattr__(self, name, value):
#
# AttributeError: 'DataFrame' object has no attribute 'amount'

# %%
#rechanging the column name 
col_name =MpesaDeposits.columns[0]
MpesaDeposits=MpesaDeposits.rename(columns = {col_name:'amount'})

# %%
#confirming the changes 
MpesaDeposits.amount
# Out:
# 0           50.00
# 1          150.00
# 2          150.00
# 3          200.00
# 4          200.00
# 5          250.00
# 6          100.00
# 7          200.00
# 8           50.00
# 9           30.00
# 10         500.00
# 11       2,000.00
# 12         200.00
# 13       2,000.00
# 14         200.00
# 15         100.00
# 16          80.00
# 17          10.00
# 18         200.00
# 19          25.00
# 20         320.00
# 21          20.00
# 22       5,000.00
# 23         500.00
# 24         250.00
# 25         250.00
# 26         150.00
# 27         800.00
# 28       3,000.00
# 29         200.00
#            ...
# 3281       100.00
# 3282       508.00
# 3283        24.00
# 3284       100.00
# 3285       100.00
# 3286        95.00
# 3287       100.00
# 3288       100.00
# 3289     1,000.00
# 3290       200.00
# 3291       500.00
# 3292       774.00
# 3293     1,000.00
# 3294     6,314.00
# 3295       900.00
# 3296        30.00
# 3297       120.00
# 3298     3,000.00
# 3299     1,000.00
# ...

# %%
#To remove white space everywhere:

MpesaDeposits.columns = MpesaDeposits.columns.str.replace(' ', '')

#To remove white space at the beginning of string:

MpesaDeposits.columns = MpesaDeposits.columns.str.lstrip()

#To remove white space at the end of string:

MpesaDeposits.columns = MpesaDeposits.columns.str.rstrip()

# To remove white space at both ends:

MpesaDeposits.columns = MpesaDeposits.columns.str.strip()

# %%
MpesaDeposits["amount"] = MpesaDeposits["amount"].str.strip()

# %%
#stripping all the white spaces and columns in the savings dataset 
MpesaDeposits["amount"] = MpesaDeposits["amount"].str.replace(',', '')

# %%
#converting the debit object to float type
MpesaDeposits["amount"] = MpesaDeposits["amount"].astype(str).astype(float)
MpesaDeposits.dtypes
# Out:
# amount              float64
# memberId              int64
# transaction_date     object
# dtype: object

# %%
MpesaDeposits.head(4)
# Out:
#    amount  memberId  transaction_date
# 0    50.0       391   9/26/2015 12:05
# 1   150.0       391   9/29/2015 14:08
# 2   150.0       391   10/6/2015 17:10
# 3   200.0       752  10/15/2015 10:29

# %%
#Let’s look at the  amount distribution
plt.subplot(121) 
sns.distplot(MpesaDeposits['amount']); 
plt.subplot(122) 
MpesaDeposits['amount'].plot.box(figsize=(16,5)) 
plt.show()
#ASSUMPTION OF LINEARITY OF INDEPENDENT VARIABLES AND LOG ODDS
# Out:
# /home/kevin_ochieng/anaconda3/lib/python3.7/site-packages/scipy/stats/stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %%
#normalizing amount using log
plt.subplot(121)
MpesaDeposits['amount'] = np.log(MpesaDeposits['amount']) 
sns.distplot(MpesaDeposits['amount']);
plt.subplot(122)
MpesaDeposits['amount'].plot.box(figsize=(16,5)) 
plt.show()
# Out:
# /home/kevin_ochieng/anaconda3/lib/python3.7/site-packages/scipy/stats/stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %%
#converting  to csv file
MpesaDeposits.reset_index(inplace = True)
MpesaDeposits.to_csv('MpesaDeposits_ded.csv', index = False)

# %%
loansummary
# Out:
#       loanId  memberId  principalAmt  repaymentAmt  repaymentperiod  \
# 0        178       391           400        420.00                1
# 1      37309       752          9000       9675.00                1
# 2      39836       752          5000       5375.00                1
# 3        891      1813           800        840.00                1
# 4       2183      1813          1200       1260.00                1
# 5      51818      2414          1200       1290.00                1
# 6      55230      2414          2500       2687.50                1
# 7      58991      2414          3000       3225.00                1
# 8      72015      2414          3100       3332.50                1
# 9        187      4790           400        420.00                1
# 10       667      4790           600        630.00                1
# 11      1631      4790         16700      17535.00                1
# 12      5574      4790          2600       2864.22                3
# ...

# %%
loansummary.dtypes
# Out:
# loanId                 int64
# memberId               int64
# principalAmt           int64
# repaymentAmt         float64
# repaymentperiod        int64
# interestAmnt         float64
# processingFee        float64
# repayment_balance    float64
# clearedstatus          int64
# dateCreated           object
# selfGuaranteed         int64
# loan_type             object
# dtype: object

# %%
#checking the missing values 
loansummary.isnull().sum()
# Out:
# loanId               0
# memberId             0
# principalAmt         0
# repaymentAmt         0
# repaymentperiod      0
# interestAmnt         0
# processingFee        0
# repayment_balance    0
# clearedstatus        0
# dateCreated          0
# selfGuaranteed       0
# loan_type            0
# dtype: int64

# %%
loansummary.head(3)
# Out:
#    loanId  memberId  principalAmt  repaymentAmt  repaymentperiod  \
# 0     178       391           400         420.0                1
# 1   37309       752          9000        9675.0                1
# 2   39836       752          5000        5375.0                1
#
#    interestAmnt  processingFee  repayment_balance  clearedstatus  \
# 0          20.0           50.0                0.0              1
# 1         450.0          225.0                0.0              1
# 2         250.0          125.0                0.0              1
#
#        dateCreated  selfGuaranteed  loan_type
# 0  6/15/2017 20:00               1  EMERGENCY
# 1   11/4/2017 9:45               1    JIPANGE
# 2  12/5/2017 16:12               1    JIPANGE

# %%
#converting object loan_type  to dummies
loansummary=pd.get_dummies(loansummary, columns=["loan_type"])

# %%
loansummary.head(3)
# Out:
#    loanId  memberId  principalAmt  repaymentAmt  repaymentperiod  \
# 0     178       391           400         420.0                1
# 1   37309       752          9000        9675.0                1
# 2   39836       752          5000        5375.0                1
#
#    interestAmnt  processingFee  repayment_balance  clearedstatus  \
# 0          20.0           50.0                0.0              1
# 1         450.0          225.0                0.0              1
# 2         250.0          125.0                0.0              1
#
#        dateCreated  selfGuaranteed  loan_type
# 0  6/15/2017 20:00               1  EMERGENCY
# 1   11/4/2017 9:45               1    JIPANGE
# 2  12/5/2017 16:12               1    JIPANGE

# %%
#taking only the numerical datasets from the loansummary
df_num=loansummary.select_dtypes(include = ['float64','int64'])
df_num.head()
# Out:
#    loanId  memberId  principalAmt  repaymentAmt  repaymentperiod  \
# 0     178       391           400         420.0                1
# 1   37309       752          9000        9675.0                1
# 2   39836       752          5000        5375.0                1
# 3     891      1813           800         840.0                1
# 4    2183      1813          1200        1260.0                1
#
#    interestAmnt  processingFee  repayment_balance  clearedstatus  \
# 0          20.0           50.0                0.0              1
# 1         450.0          225.0                0.0              1
# 2         250.0          125.0                0.0              1
# 3          40.0           50.0                0.0              1
# 4          60.0           50.0                0.0              1
#
#    selfGuaranteed
# 0               1
# 1               1
# 2               1
# 3               1
# 4               1

# %%
#dropping the identifiers
df_num.drop('loanId',axis=1,inplace=True)
df_num.drop('memberId',axis =1,inplace = True)
# Out:
# /home/kevin_ochieng/anaconda3/lib/python3.7/site-packages/pandas/core/frame.py:3697: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   errors=errors)

# %%
#displaying the numeric variables variables
df_num
# Out:
#       principalAmt  repaymentAmt  repaymentperiod  interestAmnt  \
# 0              400        420.00                1         20.00
# 1             9000       9675.00                1        450.00
# 2             5000       5375.00                1        250.00
# 3              800        840.00                1         40.00
# 4             1200       1260.00                1         60.00
# 5             1200       1290.00                1         60.00
# 6             2500       2687.50                1        125.00
# 7             3000       3225.00                1        150.00
# 8             3100       3332.50                1        155.00
# 9              400        420.00                1         20.00
# 10             600        630.00                1         30.00
# 11           16700      17535.00                1        835.00
# 12            2600       2864.22                3        264.22
# 13             596        656.58                3         60.58
# ...

# %%
#lets plot them all
df_num.hist(figsize=(16, 20), bins=50, xlabelsize=8, ylabelsize=8); # ; avoid having the matplotlib verbose informations

# %%
#dropping the clearedstatus & selfGuaranteed coz they only contain 0s and 1s
df_num.drop('clearedstatus',axis=1,inplace=True)
df_num.drop('selfGuaranteed',axis =1,inplace = True)
# Out:
# /home/kevin_ochieng/anaconda3/lib/python3.7/site-packages/pandas/core/frame.py:3697: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   errors=errors)

# %%
#a boxplot of the non-normalized data
#boxplot of the normalized dataset
boxplot = df_num.boxplot(grid=False, rot=45, fontsize=20)

# %%
#normalizing and removing outlayers in the numeric datasets
from scipy import stats
import numpy as np
z = np.abs(stats.zscore(df_num))
print(z)
# Out:
# [[0.39867799 0.39594976 0.26890767 0.294967   0.19021127 0.20151697]
#  [0.58114308 0.56763072 0.26890767 0.2722591  0.54312526 0.20151697]
#  [0.12541235 0.11993801 0.26890767 0.00843301 0.12407581 0.20151697]
#  ...
#  [0.39298136 0.38931246 0.26890767 0.29166917 0.35259292 0.06100761]
#  [0.39298136 0.38931246 0.26890767 0.29166917 0.35259292 0.06100761]
#  [0.15941936 0.15986994 0.26890767 0.1564583  0.13783009 0.57909055]]

# %%
#store only the values below the threshhold of 3
df_num1 = df_num[(z < 3).all(axis=1)]

# %%
#checking the shape 
df_num.shape
# Out:
# (1051, 6)

# %%
#standadization of the numeric variables reduces the shapes 
df_num1.shape
# Out:
# (1022, 6)

# %%
#printing the  normalized numeric variables
df_num1
# Out:
#       principalAmt  repaymentAmt  repaymentperiod  interestAmnt  \
# 0              400        420.00                1         20.00
# 1             9000       9675.00                1        450.00
# 2             5000       5375.00                1        250.00
# 3              800        840.00                1         40.00
# 4             1200       1260.00                1         60.00
# 5             1200       1290.00                1         60.00
# 6             2500       2687.50                1        125.00
# 7             3000       3225.00                1        150.00
# 8             3100       3332.50                1        155.00
# 9              400        420.00                1         20.00
# 10             600        630.00                1         30.00
# 11           16700      17535.00                1        835.00
# 12            2600       2864.22                3        264.22
# 13             596        656.58                3         60.58
# ...

# %%
#plotting the normalized datasets
#lets plot them all
df_num1.hist(figsize=(16, 20), bins=20, xlabelsize=8, ylabelsize=8); # ; avoid having the matplotlib verbose informations

# %%
# plotting multiple boxplots
import matplotlib.pyplot as plt
import numpy as np
from matplotlib.patches import Polygon

# %%
#boxplot of the normalized dataset
boxplot = df_num1.boxplot(grid=False, rot=45, fontsize=20)

# %%
#displaying the first 4 raws
loansummary.head(4)
# Out:
#    loanId  memberId  principalAmt  repaymentAmt  repaymentperiod  \
# 0     178       391           400         420.0                1
# 1   37309       752          9000        9675.0                1
# 2   39836       752          5000        5375.0                1
# 3     891      1813           800         840.0                1
#
#    interestAmnt  processingFee  repayment_balance  clearedstatus  \
# 0          20.0           50.0                0.0              1
# 1         450.0          225.0                0.0              1
# 2         250.0          125.0                0.0              1
# 3          40.0           50.0                0.0              1
#
#        dateCreated  selfGuaranteed  loan_type
# 0  6/15/2017 20:00               1  EMERGENCY
# 1   11/4/2017 9:45               1    JIPANGE
# 2  12/5/2017 16:12               1    JIPANGE
# 3    1/2/2016 8:35               1  EMERGENCY

# %%
#visualizing a count of cleared status 

loansummary['clearedstatus'].value_counts().plot.bar()

# %%
#loan summary of the cleared status with respect to loan type
loan_type=pd.crosstab(loansummary['loan_type'],loansummary['clearedstatus'])

# %%
loan_type.div(loan_type.sum(1).astype(float), axis=0).plot(kind="bar", stacked=True, figsize=(6,6)) 
plt.show()

# %%
loansummary
# Out:
#       loanId  memberId  principalAmt  repaymentAmt  repaymentperiod  \
# 0        178       391           400        420.00                1
# 1      37309       752          9000       9675.00                1
# 2      39836       752          5000       5375.00                1
# 3        891      1813           800        840.00                1
# 4       2183      1813          1200       1260.00                1
# 5      51818      2414          1200       1290.00                1
# 6      55230      2414          2500       2687.50                1
# 7      58991      2414          3000       3225.00                1
# 8      72015      2414          3100       3332.50                1
# 9        187      4790           400        420.00                1
# 10       667      4790           600        630.00                1
# 11      1631      4790         16700      17535.00                1
# 12      5574      4790          2600       2864.22                3
# ...

# %%
#We can extract each of these components into their own variables
#index = df.index
#columns = df.columns
 #values = df.values
 
x = loansummary[['memberId', 'clearedstatus']]

# %%
#displaying the selected columns 
x
# Out:
#       memberId  clearedstatus
# 0          391              1
# 1          752              1
# 2          752              1
# 3         1813              1
# 4         1813              1
# 5         2414              1
# 6         2414              1
# 7         2414              1
# 8         2414              1
# 9         4790              1
# 10        4790              1
# 11        4790              1
# 12        4790              1
# 13        4790              1
# 14        4790              1
# 15        4790              1
# 16        4790              1
# 17        4790              1
# 18        4790              1
# 19        4790              1
# 20        4790              1
# 21        4790              1
# 22        4790              1
# 23        4790              1
# 24        4790              1
# 25        4790              1
# 26        4790              1
# 27        4790              1
# 28        4790              1
# 29        4790              1
# ...

# %%
#converting cleared status to 1 foe those who have cleared 
cleared  = x.loc[x['clearedstatus'] == 1]

# %%
#grouping those who have cleared 
cleared_counts = cleared.groupby(['memberId']).count()

# %%
cleared_counts.memberId
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-111-8e85f16b3e82> in <module>()
# ----> 1 cleared_counts.memberId
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/generic.py in __getattr__(self, name)
#    4374             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    4375                 return self[name]
# -> 4376             return object.__getattribute__(self, name)
#    4377
#    4378     def __setattr__(self, name, value):
#
# AttributeError: 'DataFrame' object has no attribute 'memberId'

# %%
#rechanging the column name for memberId
col_name =cleared_counts.columns[0]
cleared_counts=cleared_counts.rename(columns = {col_name:'cleared'})

# %%
cleared_counts
# Out:
#           cleared
# memberId
# 391             1
# 752             2
# 1813            2
# 2414            4
# 4790           28
# 5162            9
# 7171           10
# 8104           22
# 9289           41
# 9916           22
# 9921           22
# 10056          54
# 16000           1
# 16273           2
# 16951           1
# 17487           1
# 24861           3
# 35596           1
# 36156           1
# 36876          35
# 40057           3
# 43365           2
# 46404          11
# 48776           3
# 53449          30
# 58928           6
# 60433          12
# 62502          14
# 66071           1
# 69003           6
# ...           ...
# 160463          3
# 160643          3
# 161725          3
# 162083          2
# 163025          1
# 163084          4
# 164218          4
# 166127          1
# 168815          1
# 169073          2
# 169387          1
# 172165          1
# 172303          2
# 172901          3
# 173425          3
# 173843          1
# 174767          1
# ...

# %%
#converting not cleared status to 0
notcleared =x.loc[x['clearedstatus'] == 0]

# %%
#counts on the number of times not cleared by member id
notcleared_counts = notcleared.groupby(['memberId']).count()

# %%
notcleared_counts.memberId
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-109-69673bf385ec> in <module>()
# ----> 1 notcleared_counts.memberId
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/generic.py in __getattr__(self, name)
#    4374             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    4375                 return self[name]
# -> 4376             return object.__getattribute__(self, name)
#    4377
#    4378     def __setattr__(self, name, value):
#
# AttributeError: 'DataFrame' object has no attribute 'memberId'

# %%
#rechanging the column name for memberId
col_name =notcleared_counts.columns[0]
notcleared_counts=notcleared_counts.rename(columns = {col_name:'notcleared'})

# %%
#convert index to column
cleared_counts['memberId'] = cleared_counts.index

# %%
#convert index to column
notcleared_counts['memberId'] = notcleared_counts.index

# %%
notcleared_counts
# Out:
#           notcleared  memberId
# memberId
# 5162               1      5162
# 8104               1      8104
# 9289               3      9289
# 9916               1      9916
# 10056              7     10056
# 16951              4     16951
# 24861              1     24861
# 36156              1     36156
# 36876              1     36876
# 40057              1     40057
# 43365              1     43365
# 46404              3     46404
# 53449              6     53449
# 58600              2     58600
# 58928              1     58928
# 60433              4     60433
# 65159              1     65159
# 66071              1     66071
# 71649              2     71649
# 71846              1     71846
# 72969              1     72969
# 84769              2     84769
# 92720              2     92720
# 95841              1     95841
# 98939              1     98939
# 101645             1    101645
# 104617             1    104617
# 107890             1    107890
# ...

# %%
#merging the two status with respect to memberid
merger = cleared_counts.set_index('memberId').combine_first(notcleared_counts.set_index('memberId')).reset_index()

# %%
merger
# Out:
#      memberId  cleared  notcleared
# 0         391      1.0         NaN
# 1         752      2.0         NaN
# 2        1813      2.0         NaN
# 3        2414      4.0         NaN
# 4        4790     28.0         NaN
# 5        5162      9.0         1.0
# 6        7171     10.0         NaN
# 7        8104     22.0         1.0
# 8        9289     41.0         3.0
# 9        9916     22.0         1.0
# 10       9921     22.0         NaN
# 11      10056     54.0         7.0
# 12      16000      1.0         NaN
# 13      16273      2.0         NaN
# 14      16951      1.0         4.0
# 15      17487      1.0         NaN
# 16      24861      3.0         1.0
# 17      35596      1.0         NaN
# 18      36156      1.0         1.0
# 19      36876     35.0         1.0
# 20      40057      3.0         1.0
# 21      43365      2.0         1.0
# 22      46404     11.0         3.0
# 23      48776      3.0         NaN
# 24      53449     30.0         6.0
# 25      58600      NaN         2.0
# ...

# %%
#replacing nulls with o
merger.fillna(0)
# Out:
#      memberId  cleared  notcleared
# 0         391      1.0         0.0
# 1         752      2.0         0.0
# 2        1813      2.0         0.0
# 3        2414      4.0         0.0
# 4        4790     28.0         0.0
# 5        5162      9.0         1.0
# 6        7171     10.0         0.0
# 7        8104     22.0         1.0
# 8        9289     41.0         3.0
# 9        9916     22.0         1.0
# 10       9921     22.0         0.0
# 11      10056     54.0         7.0
# 12      16000      1.0         0.0
# 13      16273      2.0         0.0
# 14      16951      1.0         4.0
# 15      17487      1.0         0.0
# 16      24861      3.0         1.0
# 17      35596      1.0         0.0
# 18      36156      1.0         1.0
# 19      36876     35.0         1.0
# 20      40057      3.0         1.0
# 21      43365      2.0         1.0
# 22      46404     11.0         3.0
# 23      48776      3.0         0.0
# 24      53449     30.0         6.0
# 25      58600      0.0         2.0
# ...

# %%
#frequency counts of the most active members wether defaulters or not
x['memberId'].value_counts()
# Out:
# 123489    107
# 10056      61
# 9289       44
# 53449      36
# 36876      36
# 122419     33
# 116212     29
# 4790       28
# 9916       23
# 8104       23
# 187211     22
# 9921       22
# 122825     21
# 179499     20
# 115285     19
# 119126     16
# 60433      16
# 101645     16
# 169073     15
# 92720      14
# 62502      14
# 46404      14
# 71649      13
# 150727     13
# 152759     12
# 136498     11
# 5162       10
# 128761     10
# 7171       10
# 120493      9
#          ...
# 159622      1
# 152905      1
# 159874      1
# 186201      1
# 188517      1
# 72969       1
# 178016      1
# 70623       1
# 183268      1
# 161265      1
# 35596       1
# 170748      1
# 189142      1
# 183673      1
# 156751      1
# 123577      1
# 16000       1
# 185988      1
# 17487       1
# 65159       1
# 178123      1
# 185212      1
# 160638      1
# 185216      1
# 188979      1
# 132917      1
# 179118      1
# 157044      1
# 391         1
# 108532      1
# ...

# %%
#the initial dataset
loansummary.head(2)
# Out:
#    loanId  memberId  principalAmt  repaymentAmt  repaymentperiod  \
# 0     178       391           400         420.0                1
# 1   37309       752          9000        9675.0                1
#
#    interestAmnt  processingFee  repayment_balance  clearedstatus  \
# 0          20.0           50.0                0.0              1
# 1         450.0          225.0                0.0              1
#
#        dateCreated  selfGuaranteed  loan_type
# 0  6/15/2017 20:00               1  EMERGENCY
# 1   11/4/2017 9:45               1    JIPANGE

# %%
#normalized numeric dataframe
df_num1.head(2)
# Out:
#    principalAmt  repaymentAmt  repaymentperiod  interestAmnt  processingFee  \
# 0           400         420.0                1          20.0           50.0
# 1          9000        9675.0                1         450.0          225.0
#
#    repayment_balance
# 0                0.0
# 1                0.0

# %%
df_num1[['loanId','memberId','clearedstatus','dateCreated','selfGuaranteed','loan_type']] = loansummary[['loanId','memberId','clearedstatus','dateCreated','selfGuaranteed','loan_type']]
# Out:
# /home/kevin_ochieng/anaconda3/lib/python3.7/site-packages/pandas/core/frame.py:3140: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self[k1] = value[k2]

# %%
#writing a function that selects all columns in loansummary
#that are not in df_num1 and adding to the df_num1 dataframe
df_num1['loanId'] = loansummary['loanId']
# Out:
# /home/kevin_ochieng/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
#the entity is now ready for feature engineering
df_num1.head(4)
# Out:
#    principalAmt  repaymentAmt  repaymentperiod  interestAmnt  processingFee  \
# 0           400         420.0                1          20.0           50.0
# 1          9000        9675.0                1         450.0          225.0
# 2          5000        5375.0                1         250.0          125.0
# 3           800         840.0                1          40.0           50.0
#
#    repayment_balance  loanId  memberId  clearedstatus      dateCreated  \
# 0                0.0     178       391              1  6/15/2017 20:00
# 1                0.0   37309       752              1   11/4/2017 9:45
# 2                0.0   39836       752              1  12/5/2017 16:12
# 3                0.0     891      1813              1    1/2/2016 8:35
#
#    selfGuaranteed  loan_type
# 0               1  EMERGENCY
# 1               1    JIPANGE
# 2               1    JIPANGE
# 3               1  EMERGENCY

# %%
df_num1.shape
# Out:
# (1022, 12)

# %%
loansummary.shape
# Out:
# (1051, 12)

# %%
df_num1.dtypes
# Out:
# principalAmt           int64
# repaymentAmt         float64
# repaymentperiod        int64
# interestAmnt         float64
# processingFee        float64
# repayment_balance    float64
# loanId                 int64
# memberId               int64
# clearedstatus          int64
# dateCreated           object
# selfGuaranteed         int64
# loan_type             object
# dtype: object

# %%
#converting  to csv file
apps.reset_index(inplace = True)
apps.to_csv('appsded.csv', index = False)
